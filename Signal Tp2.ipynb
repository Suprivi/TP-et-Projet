# %%
from wavtools import *
import numpy as np
import matplotlib.pyplot as plt
import numpy.fft as fft
from imtools import *

# %%
signal, freq = open_wave('flute.wav')
print(signal)
print(freq)
# Out:
# [ 0.          0.          0.         ... -0.51191748 -0.58073672
#  -0.32422864]
# 48000.0

# %%
#Exercice N°1.1
x = np.linspace(0,90000,90000)
plt.plot(x,np.sin(2*np.pi*x*440/30000),plt.axis([0,300,-1,1]))
plt.plot()
N = np.size(x)

# %%
def sinusoide(Fs, Fe, duree):
    N = Fe*duree
    tableau = np.zeros(N)
    for i in range(N):
        tableau[i] = np.sin(2*np.pi*i*Fs/Fe)
    return tableau

S = sinusoide(440,30000,3)
save_wave(S,'Question1.wav',30000)
play_wave('Question1.wav')
# Out:
# Question1.wav

# %%
#3)a
print(fft.fft(S))

plt.plot(x,np.abs(fft.fft(S)))
plt.show()
# Out:
# [1.45085104e-11+0.00000000e+00j 1.85093978e-11-3.09492289e-12j
#  1.50096867e-11+5.58515539e-12j ... 2.02263967e-11-5.99454523e-12j
#  1.50096867e-11-5.58515539e-12j 1.85093978e-11+3.09492289e-12j]

# %%
#b
plt.plot(fft.fftfreq(N,1/30000), '.')
plt.show()

# %%
#c
plt.plot(fft.fftshift(fft.fftfreq(N,1/30000)))
plt.show()

# %%
#4)
plt.plot(fft.fftshift(fft.fftfreq(N,1/30000)),fft.fftshift(np.abs(fft.fft(S))),plt.axis([-1000,1000,0,60000]))
plt.show()

# %%
#5)
x = np.linspace(0,90000,90000)
N = 90000
tableau2 =np.zeros(N)
for i in range(N):
    tableau2[i] = np.sign(np.sin(2*np.pi*i*440/30000))

print(fft.fft(tableau2))    
    
plt.plot(x,np.abs(fft.fft(tableau2)))
plt.show()

plt.plot(fft.fftshift(fft.fftfreq(N,1/30000)),fft.fftshift(np.abs(fft.fft(tableau2))))
plt.show()
# Out:
# [-5.        +0.j         -9.63892418+7.50491875j  1.35153351-5.86613052j
#  ...  0.16107296-7.62239834j  1.35153351+5.86613052j
#  -9.63892418-7.50491875j]

# %%
#6)
N = 90000
tableau3 =np.zeros(N)
for i in range(N):
    tableau3[i] = (2/np.pi)*np.arcsin(np.sin(2*np.pi*i*440/30000))

plt.plot(x,np.abs(fft.fft(tableau3)))
plt.show()

plt.plot(fft.fftshift(fft.fftfreq(N,1/30000)),fft.fftshift(np.abs(fft.fft(tableau3))))
plt.show()

# %%
S1 = sinusoide(440,30000,1)
S2 = sinusoide(600,30000,1)
Sq2 = np.concatenate((S1,S2))
save_wave(Sq2,'Question2.wav',30000)
play_wave('Question2.wav')
# Out:
# Question2.wav

# %%
#2)
N = 60000
plt.plot(fft.fftshift(fft.fftfreq(N,1/30000)),fft.fftshift(np.abs(fft.fft(Sq2))),plt.axis([-1000,1000,0,16000]))
plt.show()

# %%
#Exercice n°3
#1)
signal_flute, freq_flute = open_wave('flute.wav')
N = np.size(signal_flute)
plt.plot(fft.fftfreq(N,1/freq_flute),np.abs(fft.fft(signal_flute)),plt.axis([0,500,0,10000]))
plt.show()

#Ré

# %%
signal_basson, freq_basson = open_wave('basson.wav')
N = np.size(signal_basson)
plt.plot(fft.fftfreq(N,1/freq_basson),np.abs(fft.fft(signal_basson)),plt.axis([0,500,0,10000]))
plt.show()
#fa

# %%
signal_compose, freq_compose = open_wave('compose.wav')
N = np.size(signal_compose)
plt.plot(fft.fftfreq(N,1/freq_compose),np.abs(fft.fft(signal_compose)),plt.axis([0,700,0,4000]))
plt.show()
#Ré

# %%
#Exercice n°4
#1,2)
N = 32
f = 1
Z = np.zeros((N,N))
[n,m] = np.meshgrid(range(N),range(N))
Z[n,m] = np.cos(2*np.pi*f*m/N)
display_image(Z)
Z2 = np.zeros((N,N))
Z2[n,m] = (np.cos(2*np.pi*f*m/N)+1)*255/2
display_image(Z2)

# %%
#3)
plt.plot(np.abs(fft.fft2(Z)))
plt.show()
plt.plot(np.abs(fft.fft2(Z2)))
plt.show()

# %%
#4)
a = np.abs(fft.fft2(Z))
display_image(a)
b = np.abs(fft.fft2(Z2))
display_image(b)

# %%
a = np.abs(fft.fft2(Z))
display_image(a,vmax = 10000)
b = np.abs(fft.fft2(Z2))
display_image(b,vmax = 10000)

# %%
a = np.log10(1+np.abs(fft.fft2(Z)))
display_image(a)
b = np.log10(1+np.abs(fft.fft2(Z2)))
display_image(b)

# %%
a = fft.fftshift(np.abs(fft.fft2(Z)))
display_image(a)
b = fft.fftshift(np.abs(fft.fft2(Z2)))
display_image(b)

# %%
a = fft.fftshift(np.abs(fft.fft2(Z)))
display_image(a,vmax = 10000)
b = fft.fftshift(np.abs(fft.fft2(Z2)))
display_image(b,vmax = 10000)

# %%
a = fft.fftshift(np.log10(1+np.abs(fft.fft2(Z))))
display_image(a)
b = fft.fftshift(np.log10(1+np.abs(fft.fft2(Z2))))
display_image(b)

# %%
i = np.zeros((128,128))
i[54:74,54:74] = 255
aff_img(i,[-64,64,-64,64])
aff_img(i,xv=list(range(-64,64)),yv=list(range(-128,0)))
# Out:
# 128
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-147fe10276b6> in <module>
#       2 i[54:74,54:74] = 255
#       3 aff_img(i,[-64,64,-64,64])
# ----> 4 aff_img(i,xv=list(range(-64,64)),yv=list(range(-128,0)))
#
# ~\Desktop\Cours Université\L3 Mapi3\S5\Signal de Fourier\Signal de Fourier TP\2021-2022\imtools.py in aff_img(img, xlmm, xv, yv, now, vmin, vmax)
#     116         print(len(yv))
#     117         if type(xv) == list:
# --> 118             ax.set_xticklabels(xv[0:len(xv):int(len(xv)/8)])
#     119         else:
#     120             ax.set_xticklabels(xv[0:xv.size:int(xv.size/8)])
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in wrapper(self, *args, **kwargs)
#      61
#      62         def wrapper(self, *args, **kwargs):
# ---> 63             return get_method(self)(*args, **kwargs)
#      64
# ...

# %%
#5)
a = np.abs(fft.fft2(Z))
aff_img(a,[-N/2,N/2,-N/2,N/2])

# %%
b = np.abs(fft.fft2(Z2))
aff_img(b,[-N/2,N/2,-N/2,N/2])

# %%
a = np.log10(1+np.abs(fft.fft2(Z)))
aff_img(a,[-N/2,N/2,-N/2,N/2])

# %%
b = np.log10(1+np.abs(fft.fft2(Z2)))
aff_img(b,[-N/2,N/2,-N/2,N/2])

# %%
a = fft.fftshift(np.abs(fft.fft2(Z)))
aff_img(a,[-N/2,N/2,-N/2,N/2])

# %%
b = fft.fftshift(np.abs(fft.fft2(Z2)))
aff_img(b,[-N/2,N/2,-N/2,N/2])

# %%
a = fft.fftshift(np.log10(1+np.abs(fft.fft2(Z))))
aff_img(a,[-N/2,N/2,-N/2,N/2])

# %%
b = fft.fftshift(np.log10(1+np.abs(fft.fft2(Z2))))
aff_img(b,[-N/2,N/2,-N/2,N/2])

# %%
#8)
N = 32
f = 8
Z3 = np.zeros((N,N))
[n,m] = np.meshgrid(range(N),range(N))
Z3[n,m] = np.cos(2*np.pi*f*m/N)
display_image(Z3)

# %%
c = np.abs(fft.fft2(Z3))
display_image(c)

# %%
c = np.log10(1+np.abs(fft.fft2(Z3)))
display_image(c)

# %%
c = fft.fftshift(np.abs(fft.fft2(Z3)))
display_image(c)

# %%
c = fft.fftshift(np.log10(1+np.abs(fft.fft2(Z3))))
display_image(c)

# %%
c = np.abs(fft.fft2(Z3))
aff_img(c,[-N/2,N/2,-N/2,N/2])

# %%
c = np.log10(1+np.abs(fft.fft2(Z3)))
aff_img(c,[-N/2,N/2,-N/2,N/2])

# %%
c = fft.fftshift(np.abs(fft.fft2(Z3)))
aff_img(c,[-N/2,N/2,-N/2,N/2])

# %%
c = fft.fftshift(np.log10(1+np.abs(fft.fft2(Z3))))
aff_img(c,[-N/2,N/2,-N/2,N/2])

# %%
#9)
N = 32
fx = 4
fy = 8
Z4 = np.zeros((N,N))
[n,m] = np.meshgrid(range(N),range(N))
Z4[n,m] = np.cos(2*np.pi*(fx*m+fy*n)/N)
display_image(Z4)

# %%
d = np.abs(fft.fft2(Z4))
display_image(d)

# %%
d = np.log10(1+np.abs(fft.fft2(Z4)))
display_image(d)

# %%
d = fft.fftshift(np.abs(fft.fft2(Z4)))
display_image(d)

# %%
d = fft.fftshift(np.log10(1+np.abs(fft.fft2(Z4))))
display_image(d)

# %%
d = np.abs(fft.fft2(Z4))
aff_img(d,[-N/2,N/2,-N/2,N/2])

# %%
d = np.log10(1+np.abs(fft.fft2(Z4)))
aff_img(d,[-N/2,N/2,-N/2,N/2])

# %%
d = fft.fftshift(np.abs(fft.fft2(Z4)))
aff_img(d,[-N/2,N/2,-N/2,N/2])

# %%
d = fft.fftshift(np.log10(1+np.abs(fft.fft2(Z4))))
aff_img(d,[-N/2,N/2,-N/2,N/2])

# %%
N = 32
fx = 4
fy = 8
R = np.sqrt((2*np.pi*m/N - np.pi)**2 + (2*np.pi*n/N - np.pi)**2)
Z5 = np.zeros((N,N))
[n,m] = np.meshgrid(range(N),range(N))
Z5[n,m] = np.cos(2*np.pi*(fx*m+fy*n)/N)*np.exp(-R**2)
display_image(Z5)

# %%
e = np.abs(fft.fft2(Z5))
display_image(e)

# %%
e = np.log10(1+np.abs(fft.fft2(Z5)))
display_image(e)

# %%
e = fft.fftshift(np.abs(fft.fft2(Z5)))
display_image(e)

# %%
e = fft.fftshift(np.log10(1+np.abs(fft.fft2(Z5))))
display_image(e)

# %%
e = np.abs(fft.fft2(Z5))
aff_img(e,[-N/2,N/2,-N/2,N/2])

# %%
e = np.log10(1+np.abs(fft.fft2(Z5)))
aff_img(e,[-N/2,N/2,-N/2,N/2])

# %%
e = fft.fftshift(np.abs(fft.fft2(Z5)))
aff_img(e,[-N/2,N/2,-N/2,N/2])

# %%
e = fft.fftshift(np.log10(1+np.abs(fft.fft2(Z5))))
aff_img(e,[-N/2,N/2,-N/2,N/2])

# %%
N = 32
f = 2
Z6 = np.zeros((N,N))
[n,m] = np.meshgrid(range(N),range(N))
Z6[n,m] = np.sign(np.cos(2*np.pi*f*m/N))
display_image(Z6)

# %%
f = np.abs(fft.fft2(Z6))
display_image(f)

# %%
f = np.log10(1+np.abs(fft.fft2(Z6)))
display_image(f)

# %%
f = fft.fftshift(np.abs(fft.fft2(Z6)))
display_image(f)

# %%
f = fft.fftshift(np.log10(1+np.abs(fft.fft2(Z6))))
display_image(f)

# %%
f = np.abs(fft.fft2(Z6))
aff_img(f,[-N/2,N/2,-N/2,N/2])

# %%
f = np.log10(1+np.abs(fft.fft2(Z6)))
aff_img(f,[-N/2,N/2,-N/2,N/2])

# %%
f = fft.fftshift(np.abs(fft.fft2(Z6)))
aff_img(f,[-N/2,N/2,-N/2,N/2])

# %%
f = fft.fftshift(np.log10(1+np.abs(fft.fft2(Z6))))
aff_img(f,[-N/2,N/2,-N/2,N/2])

# %%
N = 32
fx = 2
fy = 2
Z7 = np.zeros((N,N))
[n,m] = np.meshgrid(range(N),range(N))
Z7[n,m] = np.sign(np.cos(2*np.pi*(fx*m+fy*n)/N))
display_image(Z7)

# %%
g = np.abs(fft.fft2(Z7))
display_image(g)

# %%
g = np.log10(1+np.abs(fft.fft2(Z7)))
display_image(g)

# %%
g = fft.fftshift(np.abs(fft.fft2(Z7)))
display_image(g)

# %%
g = fft.fftshift(np.log10(1+np.abs(fft.fft2(Z7))))
display_image(g)

# %%
g = np.abs(fft.fft2(Z7))
aff_img(g,[-N/2,N/2,-N/2,N/2])

# %%
g = np.log10(1+np.abs(fft.fft2(Z7)))
aff_img(g,[-N/2,N/2,-N/2,N/2])

# %%
g = fft.fftshift(np.abs(fft.fft2(Z7)))
aff_img(g,[-N/2,N/2,-N/2,N/2])

# %%
g = fft.fftshift(np.log10(1+np.abs(fft.fft2(Z7))))
aff_img(g,[-N/2,N/2,-N/2,N/2])

# %%
#12)
i = open_image('barbara.png')
N = 512
[n,m] = np.meshgrid(range(N),range(N))
Z8 = np.zeros((N,N))
R1 = (m-256)**2 + (n - 256)**2

C = fft.fft2(i)
Cs = fft.fftshift(C)
Z8 = np.abs(fft.ifft2(np.exp(-R1/200)*Cs))
aff_img(Z8.real)

# %%
R2 = (m-183)**2 + (n - 318)**2
R3 = (m-338)**2 + (n - 192)**2
R4 = (m-205)**2 + (n - 211)**2
R5 = (m-305)**2 + (n - 311)**2

C = fft.fft2(i)
Cs = fft.fftshift(C)
TotalRk = np.exp(-R1/200)*Cs+np.exp(-R2/50)*Cs+np.exp(-R3/50)*Cs+np.exp(-R4/50)*Cs+np.exp(-R5/50)*Cs
Z9 = np.abs(fft.ifft2(TotalRk))
aff_img(Z9.real)
